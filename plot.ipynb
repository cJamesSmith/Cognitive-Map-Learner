# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-32-128-128-32-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-32-0-128-32-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

# 设置绘图风格，使用科学论文常见的线条样式和颜色
# plt.style.use('seaborn-whitegrid')
# fig, ax = plt.subplots()
# ax.plot(mses1, label="mses1")
# ax.set_title("Prediction errors during training")
# ax.set_yscale("log")
# plt.legend()
# plt.show()
# plt.close(fig)

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)

fig, ax = plt.subplots()
ax.plot(x_data1, y_data1,color='blue', linewidth=2, label='nn-CML')
ax.plot(x_data2, y_data2, color='red', linewidth=2, label='CML')
ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend()

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-50-128-128-32-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-50-0-128-32-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

# 设置绘图风格，使用科学论文常见的线条样式和颜色
# plt.style.use('seaborn-whitegrid')
# fig, ax = plt.subplots()
# ax.plot(mses1, label="mses1")
# ax.set_title("Prediction errors during training")
# ax.set_yscale("log")
# plt.legend()
# plt.show()
# plt.close(fig)

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)

fig, ax = plt.subplots()
ax.plot(x_data1, y_data1,color='blue', linewidth=2, label='nn-CML')
ax.plot(x_data2, y_data2, color='red', linewidth=2, label='CML')
ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend()

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-128-32-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-0-128-32-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

# 设置绘图风格，使用科学论文常见的线条样式和颜色
# plt.style.use('seaborn-whitegrid')
# fig, ax = plt.subplots()
# ax.plot(mses1, label="mses1")
# ax.set_title("Prediction errors during training")
# ax.set_yscale("log")
# plt.legend()
# plt.show()
# plt.close(fig)

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)

fig, ax = plt.subplots()
ax.plot(x_data1, y_data1,color='blue', linewidth=2, label='nn-CML')
ax.plot(x_data2, y_data2, color='red', linewidth=2, label='CML')
ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend()

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)
fig, ax = plt.subplots()

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-128-32-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-0-128-32-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-BS-32')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-BS-32')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-128-128-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-0-128-128-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-BS-128')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-BS-128')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-128-256-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-0-128-256-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-BS-256')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-BS-256')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-128-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-0-128-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-BS-512')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-BS-512')

ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend()

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)
fig, ax = plt.subplots()

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-128-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-100-128-32-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-hidden-128')
ax.plot(x_data2, y_data2, linewidth=2, label='nn-CML-hidden-32')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-128-4-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-100-128-2-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-hidden-4')
ax.plot(x_data2, y_data2, linewidth=2, label='nn-CML-hidden-2')

ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend()

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)
fig, ax = plt.subplots()

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-200-128-2-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-200-128-2-1024-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-hidden-2-BS-512')
ax.plot(x_data2, y_data2, linewidth=2, label='nn-CML-hidden-2-BS-1024')

# 读取第一个CSV文件
csv_file_path1 = 'run-nnCML-200-128-128-256-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-200-128-128-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-hidden-128-BS-256')
ax.plot(x_data2, y_data2, linewidth=2, label='nn-CML-hidden-128-BS-512')

ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend()

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)
fig, ax = plt.subplots()

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-0-128-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-100-0-32-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='CML-hidden-128')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-hidden-32')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-100-0-4-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-100-0-2-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='CML-hidden-4')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-hidden-2')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-nnCML-100-128-128-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-128-32-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nnCML-hidden-128')
ax.plot(x_data2, y_data2, linewidth=2, label='nnCML-hidden-32')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-nnCML-100-128-4-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-100-128-2-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nnCML-hidden-4')
ax.plot(x_data2, y_data2, linewidth=2, label='nnCML-hidden-2')

ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend(ncol = 2, loc='upper right')

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 设置字体和字号
font = {'family': 'Latin Modern Roman',
        # 'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15,
        }
plt.rc('font', **font)
fig, ax = plt.subplots()

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-nnCML-200-128-128-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-nnCML-200-128-2-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='nn-CML-hidden-128')
ax.plot(x_data2, y_data2, linewidth=2, label='nn-CML-hidden-2')

# 读取第一个CSV文件
csv_file_path1 = '/home/xwc/cml/run-CML-200-0-128-512-tag-train loss.csv'  # 替换为第一个CSV文件的路径
df1 = pd.read_csv(csv_file_path1, header=None, skiprows=1)

# 提取第一个CSV文件的x和y轴数据
x_data1 = df1.iloc[1:, 1].astype(float)
y_data1 = df1.iloc[1:, 2].astype(float)

# 读取第二个CSV文件
csv_file_path2 = '/home/xwc/cml/run-CML-200-0-2-512-tag-train loss.csv'  # 替换为第二个CSV文件的路径
df2 = pd.read_csv(csv_file_path2, header=None, skiprows=1)

# 提取第二个CSV文件的x和y轴数据
x_data2 = df2.iloc[1:, 1].astype(float)
y_data2 = df2.iloc[1:, 2].astype(float)

ax.plot(x_data1, y_data1, linewidth=2, label='CML-hidden-128')
ax.plot(x_data2, y_data2, linewidth=2, label='CML-hidden-2')

ax.set_xlabel('gradient steps')
ax.set_ylabel('train loss')
ax.set_yscale("log")
# ax.set_title('test loss')
plt.legend(ncol = 2, loc='upper right')

plt.tight_layout()
# 调整布局使得图像不溢出
# plt.savefig('train_loss.svg', format='svg', bbox_inches='tight')

# 显示图形
plt.show()
